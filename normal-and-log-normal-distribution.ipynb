# %% [markdown]
# <a href="https://www.kaggle.com/satendersiwach/normal-and-log-normal-distribution?scriptVersionId=85806367" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Hi!
#
# This notebook is a gentle tutorial to differentiate between Normal distribution and Log Normal Distribution.
#
# The Jupyter Notebook and dataset are also available as a [Github repository](https://github.com/satendersiwach/normal-distribution-and-log-normal-distribution).

# %%
# Dependencies

# Standard Dependencies
import os
import numpy as np
import pandas as pd
from math import sqrt

# Visualization
from pylab import *
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics
import scipy.stats as stats
from scipy.stats import lognorm
from scipy.fftpack import fft, fftshift

# Seed for reproducability
seed = 12345
np.random.seed(seed)

# %% [markdown]
# In a normal distribution, 68% (34%+34%) of the results fall within one standard deviation, and 95% (68%+13.5%+13.5%) fall within two standard deviation, and 99.7% (95%+2.1%+2.1%) fall within 3 standard deviations.

# %%
# Plot normal distribution
mu = 0
variance = 1
sigma = sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.figure(figsize=(16,5))
plt.plot(x, stats.norm.pdf(x, mu, sigma), label='Normal Distribution')
plt.title('Normal Distribution with mean = 0 and std = 1')
plt.legend(fontsize='xx-large')
plt.show()

# %% [markdown]
# ### Log-Normal Distribution

# %% [markdown]
# The lognormal distribution differs from the normal distribution in several ways.
# A major difference is in its shape: the normal distribution is symmetrical, whereas the lognormal distribution is not.
# Because the values in a lognormal distribution are positive, they create a right-skewed curve.

# %%
# Specify standard deviation and mean
std = 1
mean = 5

# Create log-normal distribution
dist=lognorm(std,loc=mean)
x=np.linspace(0,15,200)

# Visualize log-normal distribution
plt.figure(figsize=(15,6))
plt.xlim(5, 10)
plt.plot(x,dist.pdf(x), label='log-normal PDF')
plt.plot(x,dist.cdf(x), label='log-normal CDF')
plt.legend(fontsize='xx-large')
plt.title('Visualization of log-normal PDF and CDF', fontsize='xx-large')
plt.show()
